# %% [markdown]
# # 35. Search Insert Position
#
# [Link to Problem](https://leetcode.com/problems/search-insert-position/)
#
# ### Description
#
# Given a sorted array of distinct integers and a target value, return the index if the target is found. If not, return the index where it would be if it were inserted in order.
#
# You must write an algorithm with `O(log n)` runtime complexity.
#
# **Example 1:**
# ```
# Input: nums = [1,3,5,6], target = 5
# Output: 2
# ```
#
# **Example 2:**
# ```
# Input: nums = [1,3,5,6], target = 2
# Output: 1
# ```
#
# **Example 3:**
# ```
# Input: nums = [1,3,5,6], target = 7
# Output: 4
# ```
#
# **Constraints:**
# - `1 <= nums.length <= 10^4`
# - `-10^4 <= nums[i] <= 10^4`
# - `nums` contains **distinct** values sorted in **ascending** order.
# - `-10^4 <= target <= 10^4`

# %% [markdown]
# ## My Intuition
#
# _Write down your thoughts, ideas, and insights here._
#
# - **Observations:**
#   1. We could do binary search to process sorted input.
#   2. If not in the array, the left pointer will represent the exact index where the target should be inserted to maintain sorted order.
# - **Expected approach and complexity:**
#   1. Time:  O(logn)
#   2. Space: O(1)

# %%
from typing import List

def searchInsert(nums: List[int], target: int) -> int:
    left, right = 0, len(nums)-1
    while left <= right:
        middle = (left + right)//2
        middle_val = nums[middle]
        if middle_val == target:
            return middle
        if middle_val > target:
            right = middle - 1
        else:
            left = middle + 1
    return left

if __name__ == '__main__':
    # Test Case 1
    nums1 = [1, 3, 5, 6]
    target1 = 5
    result1 = searchInsert(nums1, target1)
    print(f"Test 1 Input: nums = {nums1}, target = {target1}")
    print(f"Test 1 Output: {result1}") # Expected: 2

    # Test Case 2
    nums2 = [1, 3, 5, 6]
    target2 = 2
    result2 = searchInsert(nums2, target2)
    print(f"\nTest 2 Input: nums = {nums2}, target = {target2}")
    print(f"Test 2 Output: {result2}") # Expected: 1

    # Test Case 3
    nums3 = [1, 3, 5, 6]
    target3 = 7
    result3 = searchInsert(nums3, target3)
    print(f"\nTest 3 Input: nums = {nums3}, target = {target3}")
    print(f"Test 3 Output: {result3}") # Expected: 4
# Out:
# Test 1 Input: nums = [1, 3, 5, 6], target = 5
# Test 1 Output: 2
#
# Test 2 Input: nums = [1, 3, 5, 6], target = 2
# Test 2 Output: 1
#
# Test 3 Input: nums = [1, 3, 5, 6], target = 7
# Test 3 Output: 4
