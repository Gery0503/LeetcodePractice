# %% [markdown]
# # 459. Repeated Substring Pattern
#
# [Link to Problem](https://leetcode.com/problems/repeated-substring-pattern/)
#
# ### Description
#
# Given a non-empty string `s`, check if it can be constructed by taking a substring of it and appending multiple copies of the substring together.
#
# **Example 1:**
# ```
# Input: s = "abab"
# Output: true
# Explanation: It is the substring "ab" twice.
# ```
#
# **Example 2:**
# ```
# Input: s = "aba"
# Output: false
# ```
#
# **Example 3:**
# ```
# Input: s = "abcabcabcabc"
# Output: true
# Explanation: It is the substring "abc" four times (or "abcabc" twice).
#
# _Assume s consists of lowercase English letters only and 1 ≤ s.length ≤ 10⁴._

# %%
def repeatedSubstringPattern(s):
    return s in (s + s)[1:-1]
